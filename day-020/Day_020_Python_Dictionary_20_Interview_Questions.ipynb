# %% [markdown]
# ## Q1 — Basic access
#
# **Get Ali's salary.**

# %%
employees = {
    "Ali": 50000,
    "Sara": 60000,
    "John": 55000,
    "Neha": 70000
}

# %%
employees[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 employees[0]
#
# KeyError: 0

# %% [markdown]
# ## Q2 — Add key
#
# **Add `department = 'IT'` to Ali's dictionary.**

# %%
employees = {
    "Ali": 50000,
    "Sara": 60000,
    "John": 55000,
    "Neha": 70000
}

# %%
# Write your answer here

# %% [markdown]
# ## Q3 — Update value
#
# **Update Ali's salary to 55000.**

# %%
employees = {
    "Ali": 50000,
    "Sara": 60000,
    "John": 55000,
    "Neha": 70000
}

# %%
# Write your answer here

# %% [markdown]
# ## Q4 — Check key
#
# **Check whether `email` exists. Print Yes or No.**

# %%
employees = {
    "Ali": 50000,
    "Sara": 60000,
    "John": 55000,
    "Neha": 70000
}

# %%
# Write your answer here

# %% [markdown]
# ## Q5 — Loop keys
#
# **Print all employee names using a loop.**

# %%
employees = {
    "Ali": 50000,
    "Sara": 60000,
    "John": 55000,
    "Neha": 70000
}

# %%
# Write your answer here

# %% [markdown]
# ## Q6 — Loop values
#
# **Print all salaries using a loop.**

# %%
employees = {
    "Ali": 50000,
    "Sara": 60000,
    "John": 55000,
    "Neha": 70000
}

# %%
# Write your answer here

# %% [markdown]
# ## Q7 — Loop key/value
#
# **Print each employee name and salary using a loop.**

# %%
employees = {
    "Ali": 50000,
    "Sara": 60000,
    "John": 55000,
    "Neha": 70000
}

# %%
# Write your answer here

# %% [markdown]
# ## Q8 — High salary
#
# **Print employees with salary greater than 55000.**

# %%
employees = {
    "Ali": 50000,
    "Sara": 60000,
    "John": 55000,
    "Neha": 70000
}

# %%
# Write your answer here

# %% [markdown]
# ## Q9 — Count high salary
#
# **Count employees with salary greater than 55000.**

# %%
employees = {
    "Ali": 50000,
    "Sara": 60000,
    "John": 55000,
    "Neha": 70000
}

# %%
# Write your answer here

# %% [markdown]
# ## Q10 — Total salary
#
# **Calculate total salary using a loop.**

# %%
employees = {
    "Ali": 50000,
    "Sara": 60000,
    "John": 55000,
    "Neha": 70000
}

# %%
# Write your answer here

# %% [markdown]
# ## Q11 — Average salary
#
# **Calculate average salary using a loop.**

# %%
employees = {
    "Ali": 50000,
    "Sara": 60000,
    "John": 55000,
    "Neha": 70000
}

# %%
# Write your answer here

# %% [markdown]
# ## Q12 — Filter dictionary
#
# **Create a new dictionary containing employees with salary >= 60000.**

# %%
employees = {
    "Ali": 50000,
    "Sara": 60000,
    "John": 55000,
    "Neha": 70000
}

# %%
# Write your answer here

# %% [markdown]
# ## Q13 — Bonus salary
#
# **Using a loop, add 5000 bonus for salary >= 60000, otherwise 2000. Store final salary.**

# %%
employees = {
    "Ali": 50000,
    "Sara": 60000,
    "John": 55000,
    "Neha": 70000
}

# %%
# Write your answer here

# %% [markdown]
# ## Q14 — Maximum salary
#
# **Find the highest-paid employee using a loop. Do not use max().**

# %%
employees = {
    "Ali": 50000,
    "Sara": 60000,
    "John": 55000,
    "Neha": 70000
}

# %%
# Write your answer here

# %% [markdown]
# ## Q15 — Minimum salary
#
# **Find the lowest-paid employee using a loop. Do not use min().**

# %%
employees = {
    "Ali": 50000,
    "Sara": 60000,
    "John": 55000,
    "Neha": 70000
}

# %%
# Write your answer here

# %% [markdown]
# ## Q16 — Department filter
#
# **Print employee name and department, then print only Sales employees.**

# %%
employees = {
    "Ali": {"salary": 50000, "department": "IT"},
    "Sara": {"salary": 60000, "department": "Sales"},
    "John": {"salary": 55000, "department": "IT"},
    "Neha": {"salary": 70000, "department": "Sales"}
}

# %%
# Write your answer here

# %% [markdown]
# ## Q17 — Department count
#
# **Using a loop, count employees in each department.**

# %%
employees = {
    "Ali": {"salary": 50000, "department": "IT"},
    "Sara": {"salary": 60000, "department": "Sales"},
    "John": {"salary": 55000, "department": "IT"},
    "Neha": {"salary": 70000, "department": "Sales"}
}

# %%
# Write your answer here

# %% [markdown]
# ## Q18 — Dictionary of lists
#
# **Calculate total sales for each employee using a loop.**

# %%
sales = {
    "Ali": [10000, 12000, 15000],
    "Sara": [20000, 18000, 22000],
    "John": [9000, 11000, 10000],
    "Neha": [25000, 21000, 24000]
}

# %%
# Write your answer here

# %% [markdown]
# ## Q19 — Nested dictionary
#
# **Print Ali's salary and Sara's department.**

# %%
employees = {
    "Ali": {"salary": 50000, "department": "IT"},
    "Sara": {"salary": 60000, "department": "Sales"},
    "John": {"salary": 55000, "department": "IT"},
    "Neha": {"salary": 70000, "department": "Sales"}
}

# %%
# Write your answer here

# %% [markdown]
# ## Q20 — Interview challenge
#
# **Find average Sales salary using a loop. Do not use groupby(), mean(), or sum().**

# %%
employees = {
    "Ali": {"salary": 50000, "department": "IT"},
    "Sara": {"salary": 60000, "department": "Sales"},
    "John": {"salary": 55000, "department": "IT"},
    "Neha": {"salary": 70000, "department": "Sales"},
    "Rahul": {"salary": 65000, "department": "Sales"}
}

# %%
# Write your answer here
