# %% [markdown]
# # Python String Manipulation Interview Practice (Data Analyst - 2 Years Experience)
#
# 10 interview-style questions with unique datasets.

# %% [markdown]
# # Question 1: Clean Employee Names
#
# ```python
# import pandas as pd
#
# df = pd.DataFrame({"name":[" ali ","SARA"," john","DAVID "]})
# ```
#
# ### Task
# Clean names using strip() and title().
#
# **Focus:** Python string methods (`strip`, `lower`, `upper`, `title`, `replace`, `split`, `startswith`, `isdigit`, slicing, etc.)

# %%
import pandas as pd

df = pd.DataFrame({"name":[" ali ","SARA"," john","DAVID "]})
df['name'].str.strip().str.title()
# Out:
# 0      Ali
# 1     Sara
# 2     John
# 3    David
# Name: name, dtype: str

# %% [markdown]
# # Question 2: Extract Email Domain
#
# ```python
# import pandas as pd
#
# df = pd.DataFrame({"email":["ali@gmail.com","sara@yahoo.com","john@pw.live"]})
# ```
#
# ### Task
# Create a new column containing only the email domain.
#
# **Focus:** Python string methods (`strip`, `lower`, `upper`, `title`, `replace`, `split`, `startswith`, `isdigit`, slicing, etc.)

# %%
df = pd.DataFrame({"email":["ali@gmail.com","sara@yahoo.com","john@pw.live"]})
df['domain'] = df["email"].str.split('@').str[1]
df.head()
# Out:
#             email     domain
# 0   ali@gmail.com  gmail.com
# 1  sara@yahoo.com  yahoo.com
# 2    john@pw.live    pw.live

# %% [markdown]
# # Question 3: Replace Underscores
#
# ```python
# import pandas as pd
#
# df = pd.DataFrame({"column":["first_name","last_name","employee_id"]})
# ```
#
# ### Task
# Replace '_' with spaces and convert to Title Case.
#
# **Focus:** Python string methods (`strip`, `lower`, `upper`, `title`, `replace`, `split`, `startswith`, `isdigit`, slicing, etc.)

# %%
df = pd.DataFrame({"column":["first_name","last_name","employee_id"]})
df = df['column'].str.replace("_"," ").str.title()
df.head()
# Out:
# 0     First Name
# 1      Last Name
# 2    Employee Id
# Name: column, dtype: str

# %% [markdown]
# # Question 4: Count Vowels
#
# ```python
# import pandas as pd
#
# df = pd.DataFrame({"text":["Data Analyst","Python","SQL"]})
# ```
#
# ### Task
# Count vowels in each string.
#
# **Focus:** Python string methods (`strip`, `lower`, `upper`, `title`, `replace`, `split`, `startswith`, `isdigit`, slicing, etc.)

# %%
df = pd.DataFrame({"text":["Data Analyst","Python","SQL"]})
def count_vowels(text):
    vowels = "aeiouAEIOU"
    count = 0

    for i in text:
        if i in vowels:
            count += 1

    return count

df["vowel_count"] = df["text"].apply(count_vowels)
df
# Out:
#            text  vowel_count
# 0  Data Analyst            4
# 1        Python            1
# 2           SQL            0

# %% [markdown]
# # Question 5: Extract Numbers
#
# ```python
# import pandas as pd
#
# df = pd.DataFrame({"code":["ORD123","INV456","EMP789"]})
# ```
#
# ### Task
# Extract only the numeric characters.
#
# **Focus:** Python string methods (`strip`, `lower`, `upper`, `title`, `replace`, `split`, `startswith`, `isdigit`, slicing, etc.)

# %%
df = pd.DataFrame({"code":["ORD123","INV456","EMP789"]})
df["numbers"] = df["code"].str.extract(r"(\d+)")        
df.head()
# Out:
#      code numbers
# 0  ORD123     123
# 1  INV456     456
# 2  EMP789     789

# %% [markdown]
# # Question 6: Mask Phone Numbers
#
# ```python
# import pandas as pd
#
# df = pd.DataFrame({"phone":["9876543210","9123456789","9988776655"]})
# ```
#
# ### Task
# Mask the first 6 digits with '*'.
#
# **Focus:** Python string methods (`strip`, `lower`, `upper`, `title`, `replace`, `split`, `startswith`, `isdigit`, slicing, etc.)

# %%
df = pd.DataFrame({"phone":["9876543210","9123456789","9988776655"]})
for i in df['phone']:
    df['phone'] = i.replace(i[:6],"******")
print(df)
# Out:
#         phone
# 0  ******6655
# 1  ******6655
# 2  ******6655

# %% [markdown]
# # Question 7: Split Full Name
#
# ```python
# import pandas as pd
#
# df = pd.DataFrame({"full_name":["Ali Khan","Sara Ahmed","John Smith"]})
# ```
#
# ### Task
# Create first_name and last_name columns.
#
# **Focus:** Python string methods (`strip`, `lower`, `upper`, `title`, `replace`, `split`, `startswith`, `isdigit`, slicing, etc.)

# %%
df = pd.DataFrame({"full_name":["Ali Khan","Sara Ahmed","John Smith"]})
df['first_name'] = df['full_name'].str.split(" ").str[0]
df['last_name'] = df['full_name'].str.split(" ").str[1]
df.head()
# Out:
#     full_name first_name last_name
# 0    Ali Khan        Ali      Khan
# 1  Sara Ahmed       Sara     Ahmed
# 2  John Smith       John     Smith

# %% [markdown]
# # Question 8: Startswith
#
# ```python
# import pandas as pd
#
# df = pd.DataFrame({"product":["Laptop","Lamp","Mouse","Laser"]})
# ```
#
# ### Task
# Create a boolean column for products starting with 'La'.
#
# **Focus:** Python string methods (`strip`, `lower`, `upper`, `title`, `replace`, `split`, `startswith`, `isdigit`, slicing, etc.)

# %%
df = pd.DataFrame({"product":["Laptop","Lamp","Mouse","Laser"]})
df['new_column'] = df['product'].str.startswith('La')
df
# Out:
#   product  new_column
# 0  Laptop        True
# 1    Lamp        True
# 2   Mouse       False
# 3   Laser        True

# %% [markdown]
# # Question 9: Duplicate Emails
#
# ```python
# import pandas as pd
#
# df = pd.DataFrame({"email":["Ali@mail.com","ali@mail.com","Sara@mail.com","SARA@mail.com"]})
# ```
#
# ### Task
# Normalize emails and identify duplicates.
#
# **Focus:** Python string methods (`strip`, `lower`, `upper`, `title`, `replace`, `split`, `startswith`, `isdigit`, slicing, etc.)

# %%
df = pd.DataFrame({"email":["Ali@mail.com","ali@mail.com","Sara@mail.com","SARA@mail.com"]})
df[df['email'].str.lower().duplicated()]
# Out:
#            email
# 1   ali@mail.com
# 3  SARA@mail.com

# %% [markdown]
# # Question 10: Create Usernames
#
# ```python
# import pandas as pd
#
# df = pd.DataFrame({"name":["Ali Khan","Sara Ahmed","John Smith"]})
# ```
#
# ### Task
# Create usernames like ali_khan.
#
# **Focus:** Python string methods (`strip`, `lower`, `upper`, `title`, `replace`, `split`, `startswith`, `isdigit`, slicing, etc.)

# %%
df = pd.DataFrame({"name":["Ali Khan","Sara Ahmed","John Smith"]})
df['user_name'] = df['name'].str.replace(" ","_").str.lower()
df
# Out:
#          name   user_name
# 0    Ali Khan    ali_khan
# 1  Sara Ahmed  sara_ahmed
# 2  John Smith  john_smith
