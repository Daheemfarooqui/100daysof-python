# %% [markdown]
# # Day 015 - Pandas iloc Basic Practice
#
# 10 basic iloc questions. Each question has three separate cells: Question → DataFrame → Empty answer cell.

# %% [markdown]
# ## Question 1
#
# Select the first row.

# %%
import pandas as pd

df = pd.DataFrame({"Name":["Ali","Sara","John","David"],"Department":["Sales","HR","IT","Sales"],"Salary":[50000,45000,70000,60000]})

# %%
df.iloc[0]
# Out:
# Name            Ali
# Department    Sales
# Salary        50000
# Name: 0, dtype: object

# %% [markdown]
# ## Question 2
#
# Select the last row.

# %%
import pandas as pd

df = pd.DataFrame({"Name":["Ali","Sara","John","David"],"Department":["Sales","HR","IT","Sales"],"Salary":[50000,45000,70000,60000]})

# %%
df.iloc[-1]
# Out:
# Name          David
# Department    Sales
# Salary        60000
# Name: 3, dtype: object

# %% [markdown]
# ## Question 3
#
# Select the first two rows.

# %%
import pandas as pd

df = pd.DataFrame({"Name":["Ali","Sara","John","David"],"Department":["Sales","HR","IT","Sales"],"Salary":[50000,45000,70000,60000]})

# %%
df.iloc[0:2]
# Out:
#    Name Department  Salary
# 0   Ali      Sales   50000
# 1  Sara         HR   45000

# %% [markdown]
# ## Question 4
#
# Select rows 2 and 3.

# %%
import pandas as pd

df = pd.DataFrame({"Name":["Ali","Sara","John","David","Mary"],"Department":["Sales","HR","IT","Sales","Finance"],"Salary":[50000,45000,70000,60000,55000]})

# %%
df.iloc[[1,2]]
# Out:
#    Name Department  Salary
# 1  Sara         HR   45000
# 2  John         IT   70000

# %% [markdown]
# ## Question 5
#
# Select the first column.

# %%
import pandas as pd

df = pd.DataFrame({"Name":["Ali","Sara","John"],"Department":["Sales","HR","IT"],"Salary":[50000,45000,70000]})

# %%
df.iloc[:,[0]]
# Out:
#    Name
# 0   Ali
# 1  Sara
# 2  John

# %% [markdown]
# ## Question 6
#
# Select the first two columns.

# %%
import pandas as pd

df = pd.DataFrame({"Name":["Ali","Sara","John"],"Department":["Sales","HR","IT"],"Salary":[50000,45000,70000]})

# %%
df.iloc[:,[0,1]]
# Out:
#    Name Department
# 0   Ali      Sales
# 1  Sara         HR
# 2  John         IT

# %% [markdown]
# ## Question 7
#
# Select rows 1 to 3 and columns 0 to 1.

# %%
import pandas as pd

df = pd.DataFrame({"Name":["Ali","Sara","John","David"],"Department":["Sales","HR","IT","Sales"],"Salary":[50000,45000,70000,60000]})

# %%
df.iloc[1:4, 0:2]
# Out:
#     Name Department
# 1   Sara         HR
# 2   John         IT
# 3  David      Sales

# %% [markdown]
# ## Question 8
#
# Select only the Salary value from the third row.

# %%
import pandas as pd

df = pd.DataFrame({"Name":["Ali","Sara","John","David"],"Department":["Sales","HR","IT","Sales"],"Salary":[50000,45000,70000,60000]})

# %%
df.iloc[2,[2]]
# Out:
# Salary    70000
# Name: 2, dtype: int64

# %% [markdown]
# ## Question 9
#
# Select the last two rows and the last two columns.

# %%
import pandas as pd

df = pd.DataFrame({"Name":["Ali","Sara","John","David","Mary"],"Department":["Sales","HR","IT","Sales","Finance"],"Salary":[50000,45000,70000,60000,55000],"City":["Delhi","Mumbai","Pune","Delhi","Jaipur"]})

# %%
df.iloc[-2:,-2:]
# Out:
#   Department  Salary
# 3      Sales   60000
# 4    Finance   55000

# %% [markdown]
# ## Question 10
#
# Select rows 1, 3 and 4 with all columns.

# %%
import pandas as pd

df = pd.DataFrame({"Name":["Ali","Sara","John","David","Mary"],"Department":["Sales","HR","IT","Sales","Finance"],"Salary":[50000,45000,70000,60000,55000]})

# %%
df.iloc[0:3,:]
# Out:
#    Name Department  Salary
# 0   Ali      Sales   50000
# 1  Sara         HR   45000
# 2  John         IT   70000
