# %% [markdown]
# # Day 006 - Medium Level Python Interview Practice
#
# **Focus:** if/elif/else, for loops, nested conditions, functions.
# Difficulty: Suitable for Data Analyst / Junior Data Engineer interviews.

# %% [markdown]
# # If Conditions

# %% [markdown]
# ## Question 1
#
# ### Dataset
#
# ```python
# salary = 72000
# ```
#
# ### Task
#
# Print 'High' if salary >=70000, 'Medium' if >=50000 else 'Low'.
#
# **Write your solution in the cell below.**

# %%
# Write your answer here

# %% [markdown]
# ## Question 2
#
# ### Dataset
#
# ```python
# password = 'Python@123'
# ```
#
# ### Task
#
# Print 'Strong' if length >=8 and contains '@', else 'Weak'.
#
# **Write your solution in the cell below.**

# %%
# Write your answer here

# %% [markdown]
# ## Question 3
#
# ### Dataset
#
# ```python
# year = 2024
# ```
#
# ### Task
#
# Check whether the year is a leap year.
#
# **Write your solution in the cell below.**

# %%
# Write your answer here

# %% [markdown]
# # For Loops

# %% [markdown]
# ## Question 4
#
# ### Dataset
#
# ```python
# numbers = [10, 25, 40, 15, 60, 5]
# ```
#
# ### Task
#
# Print numbers divisible by both 5 and 2.
#
# **Write your solution in the cell below.**

# %%
# Write your answer here

# %% [markdown]
# ## Question 5
#
# ### Dataset
#
# ```python
# marks = [85, 72, 39, 90, 58]
# ```
#
# ### Task
#
# Count how many students passed (marks >=40).
#
# **Write your solution in the cell below.**

# %%
# Write your answer here

# %% [markdown]
# ## Question 6
#
# ### Dataset
#
# ```python
# cities = ['Delhi','Mumbai','Pune','Chennai']
# ```
#
# ### Task
#
# Print only cities whose name length is greater than 5.
#
# **Write your solution in the cell below.**

# %%
# Write your answer here

# %% [markdown]
# # Functions

# %% [markdown]
# ## Question 7
#
# ### Dataset
#
# ```python
# numbers = [5, 10, 15, 20, 25]
# ```
#
# ### Task
#
# Write a function to return the average without using sum() or mean().
#
# **Write your solution in the cell below.**

# %%
# Write your answer here

# %% [markdown]
# ## Question 8
#
# ### Dataset
#
# ```python
# text = 'Data Engineer Interview'
# ```
#
# ### Task
#
# Write a function to count uppercase letters.
#
# **Write your solution in the cell below.**

# %%
# Write your answer here

# %% [markdown]
# ## Question 9
#
# ### Dataset
#
# ```python
# numbers = [10, 50, 30, 80, 60]
# ```
#
# ### Task
#
# Write a function to return all numbers greater than 40.
#
# **Write your solution in the cell below.**

# %%
# Write your answer here

# %% [markdown]
# # If + Loop

# %% [markdown]
# ## Question 10
#
# ### Dataset
#
# ```python
# numbers = [3, 8, 11, 14, 19, 20]
# ```
#
# ### Task
#
# Print 'Even' or 'Odd' for every number.
#
# **Write your solution in the cell below.**

# %%
# Write your answer here

# %% [markdown]
# ## Question 11
#
# ### Dataset
#
# ```python
# employees = [('Ali',52000),('Sara',45000),('John',71000)]
# ```
#
# ### Task
#
# Print employee names whose salary is at least 50000.
#
# **Write your solution in the cell below.**

# %%
# Write your answer here

# %% [markdown]
# ## Question 12
#
# ### Dataset
#
# ```python
# words = ['python','AI','powerbi','sql','analytics']
# ```
#
# ### Task
#
# Print only words having more than 5 characters.
#
# **Write your solution in the cell below.**

# %%
# Write your answer here
